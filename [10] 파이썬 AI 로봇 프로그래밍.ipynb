# %% [markdown]
# <div style="padding: 15px; border: 5px solid transparent; border-color: transparent; margin-bottom: 20px; border-radius: 4px; color: #3c763d; background-color: #dff0d8; border-color: #d6e9c6; font-weight: bold;">
#     <br><br>
#     <div style="font-weight: bold; font-size: 40px">파이썬 AI 로봇 프로그래밍</div>
#     <div style="font-weight: bold; font-size: 20px">[10] Ipydoodle 자판기 프로젝트</div>
#     <hr style="width:80%;text-align:left;margin-left:0;border:0.5px solid green">
#     <br>
#     &#x2022; Ipydoodle을 이용해 문제를 해결한다.<br>
# </div>

# %% [markdown]
# 자판기는 알맞은 금액을 넣고 원하는 물건을 선택하면 그 물건이 나오는 일종의 무인판매기입니다.
# 영희는 이 자판기에서 가능성을 보았고, 이제는 이 자판기를 직접 만들어 사업을 하려고 합니다.
# 여러분은 영희에게 이 자판기에 들어갈 프로그램을 만들어달라고 의뢰를 받은 상황입니다.
# 여러분이 영희에게 만들어주기로 한 자판기는 다음처럼 행동합니다
#
# * 처음 자판기를 고르면 음식을 골라야 한다.
# * 음식 이름을 잘못 입력하면 오류가 난다.
# * 음식 이름을 알맞게 입력하면 그 음식을 출력한다.
#
# 영희가 의뢰한 자판기 프로그램을 개발해주세요.
#
# ![2영희 얼굴이 들어간 자판기 만들기.jpg](attachment:3367aecb-fcd6-483a-afd8-28b044b3acb7.jpg)

# %% [markdown]
# <div style="padding: 15px; border: 5px solid transparent; border-color: transparent; margin-bottom: 20px; border-radius: 4px; color: #3c763d; border-color: #d6e9c6; font-weight: bold;">
# <h2 style='font-weight: bold'>1. IpyDoodle 익히기</h2>
# </div>

# %% [markdown]
# ### 1.1. IpyDoodle을 사용해 World 및 상자, 원 그리기
# 먼저 음식을 그릴 수 있는 함수를 만들어보아요

# %% [markdown]
# #### 1.1.1. World 만들어보기
# * `World` 함수는 앞으로 우리가 생성할 여러가지 물체를 담는 공간을 나타냅니다.
# * `Box`, `Circle` 등 우리가 생성한 물체는 마지막으로 World를 실행한 곳에 나타납니다.
# * World에는 세개의 입력이 들어갑니다.
#     * `width` : 세계의 전체 가로길이입니다.
#         * 기본값은 700입니다.
#     * `height` : 세계의 전체 세로길이입니다.
#         * 기본값은 500입니다.
#     * `color`: 세계의 색깔입니다. (이번 예제에서는 사용하지 않아요)
#         * 기본값은 하얀색입니다.
#
# 문제: 자유롭게 World를 생성해주세요!

# %%
World(width = 600, height = 300, color='gray')

# %% [markdown]
# #### 1.1.2. Box 만들어보기
# * 상자는 마지막으로 World를 실행한 곳에 나타납니다.
# * Box에는 5개의 입력이 들어갑니다. (아래 그림을 참조해주세요)
#     * `x`: 상자 중심의 x 좌표를 나타냅니다.
#     * `y`: 상자 중심의 y 좌표를 나타냅니다.
#     * `width`: 상자의 가로 길이를 나타냅니다.
#     * `height`: 상자의 세로 길이를 나타냅니다.
#     * `color`: 상자의 색깔을 나타냅니다.
#
# ![2Ipydoodle에서 Box를 표현하는 방법.jpg](attachment:2ba3a154-53cc-4e42-9b6f-7d35629848da.jpg)

# %%
Box(x = 10, y = 20, width = 50, height = 20, color = 'red')

# %% [markdown]
# #### 1.1.3. Circle 만들기
# * 원은 마지막으로 World를 실행한 곳에 나타납니다.
# * Circle에는 4개의 입력이 들어갑니다.
#     * `x`: 원 중심의 x 좌표를 나타냅니다.
#     * `y`: 원 중심의 y 좌표를 나타냅니다.
#     * `radius`: 원의 반지름의 길이를 나타냅니다.
#     * `color`: 원의 색깔을 나타냅니다.

# %%
Circle(x = 10, y = 20, radius = 20, color = 'magenta')

# %% [markdown]
# ### 1.2. 모아보기
# 원과 상자는 World를 마지막으로 실행한 곳에 나타난다는거 기억하시나요?
# 이때까지 작성한 코드를 한대 모아 아래의 셀에 실행해보겠습니다.
# 이번에는 원과 상자가 아래 셀에 나타나겠죠?

# %%
World(width = 600, height = 300, color='gray')
Box(x = 10, y = 20, width = 50, height = 20, color = 'red')
Circle(x = 10, y = 20, radius = 20, color = 'magenta')

# %% [markdown]
# ### 1.3. 활용하기
# 앞서 배운 내용들을 모두 활용해서 다음의 함수 두개를 만들어주세요!
# 1. `make_food_1()`: 첫번째 음식을 그리는 함수에요.
# 2. `make_food_2()`: 두번째 음식을 그리는 함수에요.
#     * 자유롭게 구성해주세요!
#     * 함수 이름은 마음대로 정하셔도 돼요 ex) make_hamburger

# %%
def make_getorade():
    World(width = 150, height = 100, axis = False)
    Circle(x = 0, y = 15, radius = 15, color = '#EAE517')
    Box(x = 25, y = 15, width = 50, height = 30, color = '#EAE517')
    Circle(x = 49, y = 15, radius = 15, color = 'black')
    Circle(x = 50, y = 15, radius = 15, color = '#FA642C')
    

def make_powerade():
    World(width = 150, height = 100, axis = False)
    Circle(x = 0, y = 15, radius = 15, color = '#0CBDF9')
    Box(x = 25, y = 15, width = 50, height = 30, color = '#0CBDF9')
    # Circle(x = 49, y = 15, radius = 15, color = 'black')
    Circle(x = 50, y = 15, radius = 15, color = 'black')

make_getorade()
make_powerade()

# %% [markdown]
# <div style="padding: 15px; border: 5px solid transparent; border-color: transparent; margin-bottom: 20px; border-radius: 4px; color: #3c763d; border-color: #d6e9c6; font-weight: bold;">
# <h2 style='font-weight: bold'>2. 조건 구조 학습하기</h2>
# </div>

# %% [markdown]
# ### 2.1. 음식 이름 입력받기
# 앞서 우리가 영희에게 만들어주기로 한 프로그램은 다음과 같습니다.
#
# * 먼저 선택하고자 하는 음식 이름을 입력한다.
# * 음식 이름을 잘못 입력하면 오류가 난다.
# * 음식을 고르고 나면 음식에 알맞은 금액을 투입한다
# * 만약 알맞은 금액을 투입하지 않으면 오류가 난다.
# * 알맞은 음식 이름을 입력받고 알맞은 금액을 받으면 음식을 내보낸다.
#
# 너무 복잡할 땐 문제를 간단히 하면 됩니다. 음식 이름만을 입력으로 받아볼까요? 입력받은 음식을 출력해주세요.
# * 입력을 받을땐 다음처럼 받으면 됩니다.
#    ```python
#    name = input("음식 이름을 입력하세요: ")
#    ```

# %%
name = input("음식 이름을 입력하세요: ")
print(name)

# %% [markdown]
# ### 2.2. 음식 이름 비교하기

# %% [markdown]
# 우리는 입력받은 음식 이름이 특정 음식의 이름이 맞는지 비교하려고 합니다.
# 이 문제에는 비교개념이 들어갑니다. 비교문은 다음과 같이 작성합니다.
# ```python
# name = input("음식 이름을 입력하세요: ")
# print(name == "빵") # name에 입력된 값이 "빵"이라면 True를, 아니면 False를 출력합니다.
# ```
# 다음을 만족하는 프로그램을 작성해주세요.
# * 임의의 음식 이름을 정합니다.
# * 음식의 이름을 입력받습니다.
# * 입력 받은 이름이 앞서 정한 음식 이름과 동일하다면 True를, 그렇지 않다면 False를 출력합니다.

# %%
name = input("음식 이름을 입력하세요: ")
print(name == "파워에이드") # name에 입력된 값이 "빵"이라면 True를, 아니면 False를 출력합니다.

# %% [markdown]
# ### 2.3. 음식 이름 바탕으로 음식 출력해주기

# %% [markdown]
# 앞서 예제 1.3에서 우리가 만든 음식은 두가지였습니다. 음식을 입력받아 알맞은 음식을 출력할 수 있도록 해주세요.
# 이 문제에서는 조건 구조의 개념이 필요합니다. 조건문은 다음과 같이 작성합니다
# ```python
# if ("조건1"):
#     # 조건 1일때 실행할 코드
# elif ("조건 2"):
#     # 조건 2일때 실행할 코드
# else:
#     # 조건 1, 2도 아닐때 실행할 코드
# ```
#
# 다음을 만족하는 프로그램을 작성해주세요.
# 1. 음식 이름을 입력으로 받습니다.
# 2. 입력받은 음식이 <지정한 음식이름 1>이면 음식 1을, <지정한 음식이름 2>이면 음식 2를, 그 무엇도 아니면 "오류가 발생했습니다"를 출력합니다.

# %%
name = input("음식 이름을 입력하세요: ")

if name == "파워에이드":
    make_powerade()
elif name == "게토레이":
    make_getorade()
else:
    print("오류가 발생했습니다.")

# %% [markdown]
# <div style="padding: 15px; border: 5px solid transparent; border-color: transparent; margin-bottom: 20px; border-radius: 4px; color: #3c763d; border-color: #d6e9c6; font-weight: bold;">
# <h2 style='font-weight: bold'>3. 마무리</h2>
# </div>

# %% [markdown]
# 그렇게 프로그램을 사용하여 자판기 사업을 한 영희는 부자가 될 수 있었답니다 ^0^

# %% [markdown]
# ![2부자가 된 영희.jpg](attachment:c663c984-81df-48f3-930b-dda0ae6965c1.jpg)
